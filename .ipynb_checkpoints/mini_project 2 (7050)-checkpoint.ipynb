# %%
import os
import nltk
import nltk.corpus
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import string
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist
from nltk.util import bigrams, trigrams, ngrams
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
df = pd.read_csv ("train.csv")
# df.info()
# df.shape
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         60000 non-null  int64
#  1   comment    60000 non-null  object
#  2   subreddit  60000 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 937.6+ KB
# (60000, 3)

# %%
def clean_text(df):
    
    all_comments = list()
    lines = df["comment"].values.tolist()
    for text in lines:
        text = text.lower()
        
        pattern = re.compile('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
        text = pattern.sub('', text)
        
        emoji = re.compile("["
                           u"\U0001F600-\U0001FFFF"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
        text = emoji.sub(r'', text)
        
        text = re.sub(r"i'm", "i am", text)
        text = re.sub(r"he's", "he is", text)
        text = re.sub(r"she's", "she is", text)
        text = re.sub(r"that's", "that is", text)        
        text = re.sub(r"what's", "what is", text)
        text = re.sub(r"where's", "where is", text) 
        text = re.sub(r"\'ll", " will", text)  
        text = re.sub(r"\'ve", " have", text)  
        text = re.sub(r"\'re", " are", text)
        text = re.sub(r"\'d", " would", text)
        text = re.sub(r"\'ve", " have", text)
        text = re.sub(r"won't", "will not", text)
        text = re.sub(r"don't", "do not", text)
        text = re.sub(r"did't", "did not", text)
        text = re.sub(r"can't", "can not", text)
        text = re.sub(r"it's", "it is", text)
        text = re.sub(r"couldn't", "could not", text)
        text = re.sub(r"have't", "have not", text)
        text = re.sub(r"nt", "not", text)
        
        text = re.sub(r"[,.\"!@#$%^&*(){}?/;`~:<>+=-]", "", text)
        
        tokens = word_tokenize(text)
        
        table = str.maketrans('', '', string.punctuation)
        
        stripped = [w.translate(table) for w in tokens]
        words = [word for word in stripped if word.isalpha()]
        
        stop_words = set(stopwords.words("english"))
        stop_words.discard("not")
        
        words = [w for w in words if not w in stop_words]
        words = ' '.join(words)
        
        all_comments.append(words)
    return all_comments

all_comments = clean_text(df)
all_comments[0:4]
# Out:
# ['think prestige poinots not expire ever skins buy available set duration exemple year release another skin vault old one making also limitededition skin also please love god not rerelease skins need grind prestige shop would suck everyone grinded',
#  'whats going happen refused asilum appeal',
#  'anecdotal evidence anecdotal clearly everyone meanot like people not',
#  'look dude due respect music people looks like carti either caught much flak maybe senot polite post inviting discussion instead capitalizing every impactful word post carti']

# %%
len(all_comments)
# Out:
# 60000

# %%
c = all_comments
filtered_sentence = [] 
freq_count_limit = FreqDist()
lemmatizer=WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

for i in c:
    comment_tokens = word_tokenize(i)
    for words in comment_tokens:
        if words not in stop_words: 
            filtered_sentence.append(words) 
        
            limit_words = lemmatizer.lemmatize(words)
#     for word in root_words:
            freq_count_limit[limit_words.lower()]+=1
freq_count_limit
# Out:
# FreqDist({'like': 8954, 'would': 7132, 'nt': 6837, 'one': 5971, 'people': 5884, 'get': 5839, 'think': 4498, 'time': 4385, 'game': 3900, 'even': 3839, ...})

# %%
freq_count_limit.pop("nt")
freq_count_limit
# Out:
# FreqDist({'like': 8954, 'would': 7132, 'one': 5971, 'people': 5884, 'get': 5839, 'think': 4498, 'time': 4385, 'game': 3900, 'even': 3839, 'really': 3752, ...})

# %%
# list(freq_count_limit.items())

# %%
sorted(freq_count_limit.items(), key=lambda x: x[1]) #, reverse=True)
# Out:
# [('limitededition', 1),
#  ('asilum', 1),
#  ('bombadil', 1),
#  ('jenius', 1),
#  ('itwhat', 1),
#  ('unspeakable', 1),
#  ('trickenjoy', 1),
#  ('insures', 1),
#  ('ancestral', 1),
#  ('momenotarily', 1),
#  ('locust', 1),
#  ('rhoides', 1),
#  ('souris', 1),
#  ('shutd', 1),
#  ('justaccidenotally', 1),
#  ('heliocenotric', 1),
#  ('timezones', 1),
#  ('ruffle', 1),
#  ('whirlpool', 1),
#  ('tropic', 1),
#  ('bahamian', 1),
#  ('ruffleslike', 1),
#  ('spirallike', 1),
#  ('moonrises', 1),
#  ('lowinformation', 1),
#  ('phoenician', 1),
#  ('legitimization', 1),
#  ('tights', 1),
#  ('gtsaid', 1),
#  ('arakh', 1),
#  ('hami', 1),
#  ('beavis', 1),
#  ('commanded', 1),
#  ('diffirenot', 1),
#  ('mounoting', 1),
#  ('incubate', 1),
#  ('weaponmaster', 1),
#  ('maxie', 1),
#  ('brrrrrrrtttttttttttttttt', 1),
#  ('peppering', 1),
#  ('selfaggrandizing', 1),
#  ('confound', 1),
#  ('honkadonkabaroos', 1),
#  ('zootopia', 1),
#  ('tslots', 1),
#  ('suspender', 1),
#  ('toberemoved', 1),
#  ('randorf', 1),
#  ('malconotenot', 1),
#  ('daphne', 1),
#  ('caruana', 1),
#  ('galizia', 1),
#  ('foxborough', 1),
#  ('faulk', 1),
#  ('oneyard', 1),
#  ('longforgotten', 1),
#  ('hippogryph', 1),
#  ('inwork', 1),
#  ('tothe', 1),
#  ('dumbassery', 1),
#  ('fword', 1),
#  ('mladic', 1),
#  ('srebrencia', 1),
#  ('drapery', 1),
#  ('opinionsprovider', 1),
#  ('corndog', 1),
#  ('tofurkey', 1),
#  ('sammich', 1),
#  ('fridging', 1),
#  ('infinitum', 1),
#  ('requestedand', 1),
#  ('moviesyv', 1),
#  ('loosens', 1),
#  ('quickmafs', 1),
#  ('gillannebula', 1),
#  ('forbiddenlove', 1),
#  ('reciprocated', 1),
#  ('plainotiff', 1),
#  ('chuunibyo', 1),
#  ('illinotenotioned', 1),
#  ('bode', 1),
#  ('poppier', 1),
#  ('eing', 1),
#  ('footwork', 1),
#  ('veganism', 1),
#  ('squid', 1),
#  ('calamari', 1),
#  ('enhances', 1),
#  ('limper', 1),
#  ('soggier', 1),
#  ('dinneror', 1),
#  ('newfie', 1),
#  ('dudeit', 1),
#  ('stovetop', 1),
#  ('wordlessly', 1),
#  ('onebyone', 1),
#  ('speechlessness', 1),
#  ('shirayuki', 1),
#  ('misconstrue', 1),
#  ('truthperiod', 1),
#  ('nonprocedural', 1),
#  ('lightskyboxid', 1),
#  ('valuesanimations', 1),
#  ('handpainoting', 1),
#  ('rhumansbeingbros', 1),
#  ('rcatswithjobs', 1),
#  ('rpartyparrot', 1),
#  ('rtrashpandas', 1),
#  ('fuuuck', 1),
#  ('dtf', 1),
#  ('ditf', 1),
#  ('cardgame', 1),
#  ('tellstones', 1),
#  ('overwatchstyle', 1),
#  ('longhorn', 1),
#  ('possibleforce', 1),
#  ('incested', 1),
#  ('droputility', 1),
#  ('bullshi', 1),
#  ('wolfhard', 1),
#  ('targaryn', 1),
#  ('nuggies', 1),
#  ('disrespek', 1),
#  ('selfrefreshed', 1),
#  ('abolute', 1),
#  ('clawfull', 1),
#  ('purrfect', 1),
#  ('gtdumb', 1),
#  ('catfished', 1),
#  ('heisman', 1),
#  ('hyperion', 1),
#  ('endymion', 1),
#  ('miscast', 1),
#  ('hillarious', 1),
#  ('cerveca', 1),
#  ('deposed', 1),
#  ('questionit', 1),
#  ('conotinaully', 1),
#  ('landingunotil', 1),
#  ('doingtrying', 1),
#  ('nikolay', 1),
#  ('moargane', 1),
#  ('playun', 1),
#  ('summoah', 1),
#  ('monay', 1),
#  ('oaff', 1),
#  ('tahiti', 1),
#  ('shtton', 1),
#  ('massmarketed', 1),
#  ('indistinct', 1),
#  ('multinationals', 1),
#  ('sidestepping', 1),
#  ('quatom', 1),
#  ('increadible', 1),
#  ('superpostion', 1),
#  ('hinfering', 1),
#  ('threesome', 1),
#  ('unblockable', 1),
#  ('snip', 1),
#  ('weas', 1),
#  ('weacapable', 1),
#  ('handset', 1),
#  ('deadwood', 1),
#  ('moulding', 1),
#  ('multitabbing', 1),
#  ('seminormal', 1),
#  ('cetra', 1),
#  ('waaaarudooooooooo', 1),
#  ('nonlol', 1),
#  ('bronzesilver', 1),
#  ('artifical', 1),
#  ('childich', 1),
#  ('selfobsessed', 1),
#  ('egomaniacal', 1),
#  ('marcone', 1),
#  ('devicedupreehmagisk', 1),
#  ('storytheme', 1),
#  ('kingj', 1),
#  ('mainstage', 1),
#  ('inoternationals', 1),
#  ('darkshire', 1),
#  ('hellfire', 1),
#  ('lowbies', 1),
#  ('fakenot', 1),
#  ('personsomeone', 1),
#  ('yearsgif', 1),
#  ('banoters', 1),
#  ('ninjatied', 1),
#  ('headband', 1),
#  ('chrysler', 1),
#  ('крв', 1),
#  ('срп', 1),
#  ('рт', 1),
#  ('bluenose', 1),
#  ('smog', 1),
#  ('premiumpaying', 1),
#  ('galley', 1),
#  ('excolonies', 1),
#  ('womanfriend', 1),
#  ('manfriend', 1),
#  ('howabout', 1),
#  ('spagnuolo', 1),
#  ('legitimises', 1),
#  ('reassessing', 1),
#  ('richly', 1),
#  ('tbis', 1),
#  ('tje', 1),
#  ('technoooo', 1),
#  ('patbev', 1),
#  ('jumpball', 1),
#  ('recorder', 1),
#  ('cuzz', 1),
#  ('teamfighter', 1),
#  ('prinotouts', 1),
#  ('resiliency', 1),
#  ('topfrags', 1),
#  ('beefy', 1),
#  ('alita', 1),
#  ('yupppp', 1),
#  ('gtunfortunately', 1),
#  ('screed', 1),
#  ('extolling', 1),
#  ('blivet', 1),
#  ('enquirer', 1),
#  ('calus', 1),
#  ('grr', 1),
#  ('reimvested', 1),
#  ('tailor', 1),
#  ('tidalcore', 1),
#  ('hydrocore', 1),
#  ('expulsom', 1),
#  ('mourihno', 1),
#  ('lorefreak', 1),
#  ('disconnectedweird', 1),
#  ('taks', 1),
#  ('chinesemade', 1),
#  ('breeland', 1),
#  ('baggle', 1),
#  ('cuddling', 1),
#  ('askes', 1),
#  ('loui', 1),
#  ('junkball', 1),
#  ('gwg', 1),
#  ('adressed', 1),
#  ('pulsebomb', 1),
#  ('cherrypicked', 1),
#  ('logistician', 1),
#  ('chidi', 1),
#  ('idph', 1),
#  ('fot', 1),
#  ('dualies', 1),
#  ('hubristic', 1),
#  ('tousled', 1),
#  ('shitthats', 1),
#  ('oniisama', 1),
#  ('electorally', 1),
#  ('wheelin', 1),
#  ('sekou', 1),
#  ('protoindoeuropean', 1),
#  ('reconstructed', 1),
#  ('arrivalofthedraenei', 1),
#  ('fleece', 1),
#  ('fenoton', 1),
#  ('pu', 1),
#  ('chiarelli', 1),
#  ('wolkan', 1),
#  ('downeast', 1),
#  ('canadianswe', 1),
#  ('canadabut', 1),
#  ('okgo', 1),
#  ('figurewe', 1),
#  ('earhs', 1),
#  ('ownwe', 1),
#  ('energyfor', 1),
#  ('artest', 1),
#  ('noit', 1),
#  ('teabagged', 1),
#  ('shuumatsu', 1),
#  ('shitemasu', 1),
#  ('isogashii', 1),
#  ('sukutte', 1),
#  ('moratte', 1),
#  ('worldend', 1),
#  ('signalboosting', 1),
#  ('lazard', 1),
#  ('sunotv', 1),
#  ('foxnews', 1),
#  ('bigsoccer', 1),
#  ('urologist', 1),
#  ('enlargemenot', 1),
#  ('takaradasalute', 1),
#  ('urchin', 1),
#  ('mchimbas', 1),
#  ('sone', 1),
#  ('writ', 1),
#  ('novorossiysk', 1),
#  ('heavydrinker', 1),
#  ('joemel', 1),
#  ('remanded', 1),
#  ('affray', 1),
#  ('wormwood', 1),
#  ('courtappoinoted', 1),
#  ('abdul', 1),
#  ('rahman', 1),
#  ('fracas', 1),
#  ('medallion', 1),
#  ('gabrielle', 1),
#  ('suge', 1),
#  ('wikid', 1),
#  ('manbackstabbers', 1),
#  ('cddvd', 1),
#  ('recordsmona', 1),
#  ('morison', 1),
#  ('tenotative', 1),
#  ('jadakiss', 1),
#  ('tyga', 1),
#  ('tsun', 1),
#  ('statsraidbots', 1),
#  ('stateweights', 1),
#  ('statweight', 1),
#  ('poens', 1),
#  ('cleavecouncil', 1),
#  ('mdungeons', 1),
#  ('focussing', 1),
#  ('bossfights', 1),
#  ('councilfaqul', 1),
#  ('multidotting', 1),
#  ('afflocks', 1),
#  ('addphase', 1),
#  ('tegel', 1),
#  ('barbecue', 1),
#  ('guangdong', 1),
#  ('shimada', 1),
#  ('stopcensor', 1),
#  ('coexist', 1),
#  ('saidblizzards', 1),
#  ('synesthesia', 1),
#  ('karsa', 1),
#  ('hylinot', 1),
#  ('nemisis', 1),
#  ('hasbro', 1),
#  ('coyld', 1),
#  ('dreamworks', 1),
#  ('wdas', 1),
#  ('likelydemocratic', 1),
#  ('wisconsinite', 1),
#  ('respondanots', 1),
#  ('debater', 1),
#  ('revoking', 1),
#  ('counoterterrorism', 1),
#  ('persaunot', 1),
#  ('leavin', 1),
#  ('rniceguys', 1),
#  ('qer', 1),
#  ('administratioan', 1),
#  ('ursula', 1),
#  ('andwhat', 1),
#  ('recklessness', 1),
#  ('siegebreaker', 1),
#  ('whelming', 1),
#  ('picapics', 1),
#  ('punctuated', 1),
#  ('fwotd', 1),
#  ('awardworthy', 1),
#  ('sexyness', 1),
#  ('sexier', 1),
#  ('retell', 1),
#  ('zoth', 1),
#  ('kawasumi', 1),
#  ('nonleadcandidates', 1),
#  ('aloha', 1),
#  ('goodresults', 1),
#  ('assdribble', 1),
#  ('rebelling', 1),
#  ('assasinations', 1),
#  ('bcn', 1),
#  ('hidy', 1),
#  ('nurk', 1),
#  ('quietbutstrong', 1),
#  ('mosrite', 1),
#  ('spree', 1),
#  ('becosue', 1),
#  ('pinker', 1),
#  ('cherrypick', 1),
#  ('sixyearold', 1),
#  ('kaihi', 1),
#  ('existanot', 1),
#  ('zidormi', 1),
#  ('beggar', 1),
#  ('rastakhan', 1),
#  ('rollingcounots', 1),
#  ('pspspspsps', 1),
#  ('cheeseit', 1),
#  ('transferts', 1),
#  ('transfert', 1),
#  ('uselessly', 1),
#  ('zedyasuoakalikharengar', 1),
#  ('devoit', 1),
#  ('breathalyzer', 1),
#  ('swab', 1),
#  ('uautolovepon', 1),
#  ('refunded', 1),
#  ('grogeous', 1),
#  ('picnic', 1),
#  ('icky', 1),
#  ('reenable', 1),
#  ('fainoted', 1),
#  ('roor', 1),
#  ('crosschecking', 1),
#  ('erection', 1),
#  ('dosen', 1),
#  ('redditfags', 1),
#  ('bandwadgon', 1),
#  ('topson', 1),
#  ('quickie', 1),
#  ('quicky', 1),
#  ('pruduct', 1),
#  ('lea', 1),
#  ('cordial', 1),
#  ('periodt', 1),
#  ('roadway', 1),
#  ('notime', 1),
#  ('pesticidesherbicides', 1),
#  ('misclick', 1),
#  ('cherubi', 1),
#  ('lonnie', 1),
#  ('incorruptible', 1),
#  ('leukemia', 1),
#  ('chinook', 1),
#  ('incessanot', 1),
#  ('thattty', 1),
#  ('rootless', 1),
#  ('gtdisrespect', 1),
#  ('gtstoakley', 1),
#  ('differenotthat', 1),
#  ('yinyang', 1),
#  ('goodevil', 1),
#  ('bff', 1),
#  ('beforeafter', 1),
#  ('sciencemedia', 1),
#  ('bettershaco', 1),
#  ('fandango', 1),
#  ('momager', 1),
#  ('qris', 1),
#  ('scienotism', 1),
#  ('aphorism', 1),
#  ('degrasse', 1),
#  ('signifier', 1),
#  ('signifides', 1),
#  ('cleganebowl', 1),
#  ('sepsis', 1),
#  ('vindicated', 1),
#  ('thowhat', 1),
#  ('sigourney', 1),
#  ('actuallyplaying', 1),
#  ('willll', 1),
#  ('teraeven', 1),
#  ('instaqueued', 1),
#  ('taquitos', 1),
#  ('vayas', 1),
#  ('cuenotaen', 1),
#  ('configuración', 1),
#  ('busques', 1),
#  ('comenotarios', 1),
#  ('ajenos', 1),
#  ('cambiar', 1),
#  ('esponotáneamenote', 1),
#  ('castellanos', 1),
#  ('permanenotemenote', 1),
#  ('sajones', 1),
#  ('haya', 1),
#  ('sido', 1),
#  ('ayuda', 1),
#  ('wading', 1),
#  ('gatari', 1),
#  ('idiocyincompetence', 1),
#  ('votekicks', 1),
#  ('votekicking', 1),
#  ('cctv', 1),
#  ('nightsdays', 1),
#  ('toolmakingwonder', 1),
#  ('buffy', 1),
#  ('leighton', 1),
#  ('meester', 1),
#  ('tessa', 1),
#  ('krystin', 1),
#  ('arnie', 1),
#  ('angler', 1),
#  ('strider', 1),
#  ('galkochan', 1),
#  ('middleback', 1),
#  ('postions', 1),
#  ('lowhigh', 1),
#  ('postclimatechange', 1),
#  ('litiganot', 1),
#  ('caselaw', 1),
#  ('rica', 1),
#  ('domincan', 1),
#  ('donged', 1),
#  ('seene', 1),
#  ('calgon', 1),
#  ('emailmobile', 1),
#  ('textemail', 1),
#  ('securely', 1),
#  ('sectorial', 1),
#  ('inbreeding', 1),
#  ('leewayliberty', 1),
#  ('substanotiative', 1),
#  ('dekomorinibutani', 1),
#  ('brazenly', 1),
#  ('chuunirelated', 1),
#  ('juxtaposed', 1),
#  ('embarrassedanxious', 1),
#  ('unconcerned', 1),
#  ('inotdoctrination', 1),
#  ('infrastrcuture', 1),
#  ('releasespropaganda', 1),
#  ('fdi', 1),
#  ('ireli', 1),
#  ('exterminates', 1),
#  ('archway', 1),
#  ('metabolism', 1),
#  ('heavycom', 1),
#  ('dod', 1),
#  ('drunkour', 1),
#  ('realmdimensionwhatever', 1),
#  ('branthrough', 1),
#  ('fathernk', 1),
#  ('bodythe', 1),
#  ('writhe', 1),
#  ('bloodflow', 1),
#  ('strangulation', 1),
#  ('constricted', 1),
#  ('lollll', 1),
#  ('terribleness', 1),
#  ('overfunds', 1),
#  ('enotrained', 1),
#  ('barriersshields', 1),
#  ('firestrike', 1),
#  ('anotivaxxerhomeopathy', 1),
#  ('impartiality', 1),
#  ('rnevertellmetheodds', 1),
#  ('wackamole', 1),
#  ('guildless', 1),
#  ('puuusay', 1),
#  ('rse', 1),
#  ('infringes', 1),
#  ('showreality', 1),
#  ('moderated', 1),
#  ('mandel', 1),
#  ('pnc', 1),
#  ('chg', 1),
#  ('alrdy', 1),
#  ('lifestealing', 1),
#  ('moa', 1),
#  ('zines', 1),
#  ('gtbest', 1),
#  ('lactose', 1),
#  ('reoffending', 1),
#  ('jocklooking', 1),
#  ('filmheroes', 1),
#  ('superracist', 1),
#  ('unconscionable', 1),
#  ('uecoastman', 1),
#  ('maxmilien', 1),
#  ('sanjay', 1),
#  ('nguyen', 1),
#  ('mcmanaway', 1),
#  ('rankandfile', 1),
#  ('ajj', 1),
#  ('tsugumomo', 1),
#  ('watchin', 1),
#  ('privelege', 1),
#  ('gtpopulist', 1),
#  ('characterized', 1),
#  ('scapegoating', 1),
#  ('oneway', 1),
#  ('alliterative', 1),
#  ('fonz', 1),
#  ('nonenglish', 1),
#  ('medival', 1),
#  ('catharsis', 1),
#  ('hera', 1),
#  ('slinking', 1),
#  ('cuphead', 1),
#  ('logsgear', 1),
#  ('rhe', 1),
#  ('weekas', 1),
#  ('hinest', 1),
#  ('grillmaster', 1),
#  ('cabana', 1),
#  ('regult', 1),
#  ('prlegal', 1),
#  ('shhhhhhthis', 1),
#  ('nikolas', 1),
#  ('makoto', 1),
#  ('shinkai', 1),
#  ('fansubs', 1),
#  ('ultrapopular', 1),
#  ('terribad', 1),
#  ('vetoed', 1),
#  ('marmalade', 1),
#  ('bshort', 1),
#  ('fooked', 1),
#  ('abilitydesire', 1),
#  ('stanger', 1),
#  ('rtp', 1),
#  ('nightmarepremonition', 1),
#  ('disproportional', 1),
#  ('olney', 1),
#  ('invertebrate', 1),
#  ('vertebrate', 1),
#  ('flaccos', 1),
#  ('castor', 1),
#  ('lyft', 1),
#  ('rampage', 1),
#  ('geo', 1),
#  ('hooman', 1),
#  ('kenyain', 1),
#  ('nairobi', 1),
#  ('darkened', 1),
#  ('darken', 1),
#  ('ellenberg', 1),
#  ('exoticgenetix', 1),
#  ('notill', 1),
#  ('regularsized', 1),
#  ('gttheramore', 1),
#  ('summonded', 1),
#  ('jaedon', 1),
#  ('nuetral', 1),
#  ('kiren', 1),
#  ('lakersclippers', 1),
#  ('brbrbrbrbrbrbrbrbrbrbrbrbrbrbbrbrbrb', 1),
#  ('pourquoi', 1),
#  ('auraitil', 1),
#  ('droit', 1),
#  ('cajuste', 1),
#  ('slowmo', 1),
#  ('emmm', 1),
#  ('ingest', 1),
#  ('cte', 1),
#  ('onetime', 1),
#  ('manhours', 1),
#  ('risen', 1),
#  ('threefold', 1),
#  ('railconstruction', 1),
#  ('shiftmovemenot', 1),
#  ('zany', 1),
#  ('parallax', 1),
#  ('deftones', 1),
#  ('godflesh', 1),
#  ('gorguts', 1),
#  ('luminiferous', 1),
#  ('immolation', 1),
#  ('utilitarian', 1),
#  ('septicflesh', 1),
#  ('skeletonwitch', 1),
#  ('devouring', 1),
#  ('radianot', 1),
#  ('trivium', 1),
#  ('errorzone', 1),
#  ('windhand', 1),
#  ('rnd', 1),
#  ('cbdcannabis', 1),
#  ('seiko', 1),
#  ('remarkablesimply', 1),
#  ('valldigna', 1),
#  ('climactic', 1),
#  ('inotercom', 1),
#  ('westjets', 1),
#  ('tumble', 1),
#  ('msmr', 1),
#  ('blorp', 1),
#  ('stipulate', 1),
#  ('pressurize', 1),
#  ('firstprinoting', 1),
#  ('wiredup', 1),
#  ('greenish', 1),
#  ('rescind', 1),
#  ('rgifs', 1),
#  ('imagebased', 1),
#  ('popularsubreddititis', 1),
#  ('conotagious', 1),
#  ('powerfanotasy', 1),
#  ('dagobah', 1),
#  ('consitanot', 1),
#  ('buttclenching', 1),
#  ('husbandry', 1),
#  ('cellmate', 1),
#  ('commissary', 1),
#  ('dickstacy', 1),
#  ('porco', 1),
#  ('rosso', 1),
#  ('romanoticization', 1),
#  ('hikoutei', 1),
#  ('jidai', 1),
#  ('hospitalisés', 1),
#  ('lowrisk', 1),
#  ('lowprofit', 1),
#  ('deconfirms', 1),
#  ('hajek', 1),
#  ('tastey', 1),
#  ('animeonly', 1),
#  ('punctuality', 1),
#  ('kareemervingmoses', 1),
#  ('lamenoted', 1),
#  ('boundless', 1),
#  ('cfx', 1),
#  ('koufax', 1),
#  ('familyguyostrichgif', 1),
#  ('zum', 1),
#  ('shavenheaded', 1),
#  ('ratchaburi', 1),
#  ('videographer', 1),
#  ('euphemistically', 1),
#  ('digester', 1),
#  ('childrenits', 1),
#  ('survivalist', 1),
#  ('cumshot', 1),
#  ('ahortest', 1),
#  ('vibrato', 1),
#  ('gilbertos', 1),
#  ('horsing', 1),
#  ('usury', 1),
#  ('congeals', 1),
#  ('sinus', 1),
#  ('rivaled', 1),
#  ('chsracter', 1),
#  ('thccbd', 1),
#  ('sturdierstronger', 1),
#  ('sherly', 1),
#  ('essencial', 1),
#  ('mpc', 1),
#  ('dooty', 1),
#  ('atill', 1),
#  ('rebooting', 1),
#  ('anotiforce', 1),
#  ('espi', 1),
#  ('spo', 1),
#  ('heatles', 1),
#  ('iceblock', 1),
#  ('losdamage', 1),
#  ('approving', 1),
#  ('quebecors', 1),
#  ('emoted', 1),
#  ('doubtlessly', 1),
#  ('obviouslu', 1),
#  ('geeb', 1),
#  ('meryl', 1),
#  ('streep', 1),
#  ('ufc', 1),
#  ('urbansmile', 1),
#  ('restock', 1),
#  ('carer', 1),
#  ('coddled', 1),
#  ('reenact', 1),
#  ('climaxrelease', 1),
#  ('setlist', 1),
#  ('nonanime', 1),
#  ('ninenine', 1),
#  ('riverdale', 1),
#  ('littorio', 1),
#  ('wiiu', 1),
#  ('rgaming', 1),
#  ('handsomeness', 1),
#  ('struth', 1),
#  ('drongo', 1),
#  ('gtunpopular', 1),
#  ('janitorsfacilities', 1),
#  ('midshift', 1),
#  ('clocked', 1),
#  ('disconotinued', 1),
#  ('ada', 1),
#  ('sponser', 1),
#  ('oilconcenotrate', 1),
#  ('bsite', 1),
#  ('itthat', 1),
#  ('meyou', 1),
#  ('poinotswise', 1),
#  ('hačeks', 1),
#  ('punishedn', 1),
#  ('volvo', 1),
#  ('snk', 1),
#  ('leagueaverage', 1),
#  ('braidinotercourse', 1),
#  ('familychildren', 1),
#  ('hksar', 1),
#  ('unibomber', 1),
#  ('cyberneticians', 1),
#  ('donella', 1),
#  ('weinschenk', 1),
#  ('seekingreward', 1),
#  ('neuroscienotist', 1),
#  ('compulsive', 1),
#  ('oblige', 1),
#  ('reverseengineer', 1),
#  ('cybernetically', 1),
#  ('speculator', 1),
#  ('amagami', 1),
#  ('lafrieneire', 1),
#  ('kanada', 1),
#  ('sockpuppet', 1),
#  ('gtgttanguy', 1),
#  ('gtbig', 1),
#  ('gtgtwith', 1),
#  ('ndmobele', 1),
#  ('schetyna', 1),
#  ('sigmoira', 1),
#  ('herniated', 1),
#  ('bronzeplat', 1),
#  ('topbottom', 1),
#  ('toptier', 1),
#  ('jel', 1),
#  ('onaj', 1),
#  ('što', 1),
#  ('jebo', 1),
#  ('palliative', 1),
#  ('cheerfulness', 1),
#  ('emits', 1),
#  ('nonchildproof', 1),
#  ('nitroglycerin', 1),
#  ('hackey', 1),
#  ('cowichan', 1),
#  ('malahat', 1),
#  ('provincially', 1),
#  ('boxofficemojo', 1),
#  ('weedwick', 1),
#  ('litany', 1),
#  ('techlash', 1),
#  ('musicstreaming', 1),
#  ('softwaremaker', 1),
#  ('preinoternet', 1),
#  ('eurofacebook', 1),
#  ('techangst', 1),
#  ('poohpoohed', 1),
#  ('gigeconomy', 1),
#  ('discomfited', 1),
#  ('echoed', 1),
#  ('infecting', 1),
#  ('inacceptable', 1),
#  ('fumed', 1),
#  ('franck', 1),
#  ('riester', 1),
#  ('quinotessenotially', 1),
#  ('abortive', 1),
#  ('scholz', 1),
#  ('surest', 1),
#  ('visàvis', 1),
#  ('margrethe', 1),
#  ('techbashing', 1),
#  ('cernovich', 1),
#  ('ciamella', 1),
#  ('greyjoys', 1),
#  ('playerdevelopmenot', 1),
#  ('abundanot', 1),
#  ('gtcompanies', 1),
#  ('elijah', 1),
#  ('aes', 1),
#  ('sedai', 1),
#  ('herat', 1),
#  ('mazare', 1),
#  ('sharif', 1),
#  ('baghdad', 1),
#  ('hypocrecy', 1),
#  ('democracyfreedom', 1),
#  ('bathstarvation', 1),
#  ('joerger', 1),
#  ('crib', 1),
#  ('hawksbros', 1),
#  ('relevel', 1),
#  ('outlash', 1),
#  ('slugging', 1),
#  ('alleviated', 1),
#  ('horrendus', 1),
#  ('victoriabut', 1),
#  ('redneckism', 1),
#  ('bellyache', 1),
#  ('regularpost', 1),
#  ('kibler', 1),
#  ('sketchiest', 1),
#  ('waxshatter', 1),
#  ('liquidized', 1),
#  ('recrystallized', 1),
#  ('fatslipids', 1),
#  ('hateforprofit', 1),
#  ('coulter', 1),
#  ('coco', 1),
#  ('rtr', 1),
#  ('aboot', 1),
#  ('misinformedconfused', 1),
#  ('pickpp', 1),
#  ('baity', 1),
#  ('kippa', 1),
#  ('gthopefully', 1),
#  ('namestnikov', 1),
#  ('upmjinxhenotai', 1),
#  ('wistfully', 1),
#  ('dangerzone', 1),
#  ('sirtaki', 1),
#  ('ouzo', 1),
#  ('webassign', 1),
#  ('willful', 1),
#  ('gaunot', 1),
#  ('digitize', 1),
#  ('molecular', 1),
#  ('hypothesize', 1),
#  ('piche', 1),
#  ('watertown', 1),
#  ('plied', 1),
#  ('aftercredit', 1),
#  ('rbostonceltics', 1),
#  ('schulz', 1),
#  ('reddi', 1),
#  ('vuc', 1),
#  ('privatisation', 1),
#  ('creditworthy', 1),
#  ('strategize', 1),
#  ('cheapen', 1),
#  ('fortissimo', 1),
#  ('forte', 1),
#  ('onetricks', 1),
#  ('birdseye', 1),
#  ('pringles', 1),
#  ('metamorphosed', 1),
#  ('routing', 1),
#  ('usmca', 1),
#  ('cusma', 1),
#  ('fiveeyes', 1),
#  ('rbarry', 1),
#  ('classing', 1),
#  ('retried', 1),
#  ('toobin', 1),
#  ('litigation', 1),
#  ('decolonization', 1),
#  ('enshrine', 1),
#  ('unsubed', 1),
#  ('unbecoming', 1),
#  ('hanzogenii', 1),
#  ('raytracing', 1),
#  ('adulation', 1),
#  ('youngstudenot', 1),
#  ('macewan', 1),
#  ('edmonotonmill', 1),
#  ('calgarycenoter', 1),
#  ('calgaryskyview', 1),
#  ('sheraton', 1),
#  ('cfl', 1),
#  ('pennanots', 1),
#  ('plomb', 1),
#  ('pétard', 1),
#  ('russoturkish', 1),
#  ('danotic', 1),
#  ('inotance', 1),
#  ('fabrication', 1),
#  ('desegregation', 1),
#  ('ytz', 1),
#  ('fungal', 1),
#  ('bronchitis', 1),
#  ('fiscallysince', 1),
#  ('rescanned', 1),
#  ('fter', 1),
#  ('rusted', 1),
#  ('daybreak', 1),
#  ('homecoming', 1),
#  ('absolutley', 1),
#  ('hitchin', 1),
#  ('chidlren', 1),
#  ('flanked', 1),
#  ('criminalizing', 1),
#  ('caitlin', 1),
#  ('connors', 1),
#  ('mrrl', 1),
#  ('rerolls', 1),
#  ('carousel', 1),
#  ('inoternets', 1),
#  ('aikman', 1),
#  ('grps', 1),
#  ('sympathiser', 1),
#  ('woeber', 1),
#  ('marsch', 1),
#  ('showmanship', 1),
#  ('infectiously', 1),
#  ('excitable', 1),
#  ('earings', 1),
#  ('bemoaning', 1),
#  ('notfuckingcare', 1),
#  ('conotenotionous', 1),
#  ('uyghur', 1),
#  ('marijunana', 1),
#  ('nbastreams', 1),
#  ('canopy', 1),
#  ('blurring', 1),
#  ('circularly', 1),
#  ('headtoe', 1),
#  ('teammtaes', 1),
#  ('efg', 1),
#  ('keystroke', 1),
#  ('juggler', 1),
#  ('paella', 1),
#  ('whearas', 1),
#  ...]

# %%
len(freq_count_limit)
# Out:
# 52715

# %%
# lists = freq_count_limit.items()

# x, y = zip(*lists)

# %%
# c = freq_count_limit
# freq_count_stem = FreqDist()
# stemmer= PorterStemmer()

# for i in c:
#     comment_tokens = word_tokenize(i)
#     for words in comment_tokens:
#         stem_words = stemmer.stem(words)
# #     for word in root_words:
#         freq_count_stem[stem_words.lower()]+=1
# freq_count_stem

# %%
# len(freq_count_stem)

# %%
# fdist_top10 = freq_count_limit.most_common(10) #[-10:]
# fdist_top10

# %%
# quotes_biogram = list(nltk.bigrams(freq_count_stem))
# quotes_biogram

# %%
# df.groupby('subreddit').describe()

# %%
# community_dummies = df['subreddit'].str.get_dummies(sep=' ')
# community_dummies[:]

# %%
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(df.comment,df., test_size=0.2)

# %%
# from sklearn.feature_extraction.text import CountVectorizer
# v = CountVectorizer()
# X_train_count = v.fit_transform(X_train.values)
# X_train_count.toarray()[:20]

# %%
# from sklearn.naive_bayes import MultinomialNB
# model = MultinomialNB()
# model.fit(X_train_count,y_train)

# %%
# # noinspection SpellCheckingInspection
# class NaiveBayesClassifier(object):
#     def __init__(self, n_gram=1, printing=False):
#         self.prior = defaultdict(int)
#         self.logprior = {}
#         self.bigdoc = defaultdict(list)
#         self.loglikelihoods = defaultdict(defaultdict)
#         self.V = []
#         self.n = n_gram

#     def compute_prior_and_bigdoc(self, training_set, training_labels):
        
#         for x, y in zip(training_set, training_labels):
#             all_words = x.split(" ")
#             if self.n == 1:
#                 grams = all_words
#             else:
#                 grams = self.words_to_grams(all_words)

#             self.prior[y] += len(grams)
#             self.bigdoc[y].append(x)

#     def compute_vocabulary(self, documents):
#         vocabulary = set()

#         for doc in documents:
#             for word in doc.split(" "):
#                 vocabulary.add(word.lower())

#         return vocabulary

#     def count_word_in_classes(self):
#         counts = {}
#         for c in list(self.bigdoc.keys()):
#             docs = self.bigdoc[c]
#             counts[c] = defaultdict(int)
#             for doc in docs:
#                 words = doc.split(" ")
#                 for word in words:
#                     counts[c][word] += 1

#         return counts

#     def train(self, training_set, training_labels, alpha=1):
#         # Get number of documents
#         N_doc = len(training_set)

#         # Get vocabulary used in training set
#         self.V = self.compute_vocabulary(training_set)

#         # Create bigdoc
#         for x, y in zip(training_set, training_labels):
#             self.bigdoc[y].append(x)

#         # Get set of all classes
#         all_classes = set(training_labels)

#         # Compute a dictionary with all word counts for each class
#         self.word_count = self.count_word_in_classes()

#         # For each class
#         for c in all_classes:
#             # Get number of documents for that class
#             N_c = float(sum(training_labels == c))

#             # Compute logprior for class
#             self.logprior[c] = np.log(N_c / N_doc)

#             # Calculate the sum of counts of words in current class
#             total_count = 0
#             for word in self.V:
#                 total_count += self.word_count[c][word]

#             # For every word, get the count and compute the log-likelihood for this class
#             for word in self.V:
#                 count = self.word_count[c][word]
#                 self.loglikelihoods[c][word] = np.log((count + alpha) / (total_count + alpha * len(self.V)))

#     def predict(self, test_doc):
#         sums = {
#             0: 0,
#             1: 0,
#         }
#         for c in self.bigdoc.keys():
#             sums[c] = self.logprior[c]
#             words = test_doc.split(" ")
#             for word in words:
#                if word in self.V:
#                    sums[c] += self.loglikelihoods[c][word]

#         return sums

# %%
# NBclassifier = NaiveBayesClassifier(n_gram=1)
# NBclassifier.train(X_train, y_train)

# %%
# result = NBclassifier.predict(test)
# print(np.exp(result))
